# %% [markdown]
# <a href="https://colab.research.google.com/github/armandoordonez/eda_couse/blob/main/Pipeline_Experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Based on https://towardsdatascience.com/pipelines-custom-transformers-in-scikit-learn-the-step-by-step-guide-with-python-code-4a7d9b068156

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.compose import TransformedTargetRegressor
from sklearn.pipeline import FeatureUnion, Pipeline, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LinearRegression

# %%
url = 'https://github.com/carlosjara/MCD_FAII/blob/main/FAII/Talleres/Taller_Practico/data/df_train.csv?raw=true'
#data = pd.read_excel("content/datosEmpleo.xlsx",index_col='mes',parse_dates=True)
df = pd.read_csv(url, sep=';')
print(df.shape)
df.head(3)
# Out:
# (1000, 42)
#   GENERO ESTADO_CIVIL          FECHA_NACIMIENTO  CODIGO_SEDE MULTI_CANCER  \
# 0      F           SO   9/2/1954, 7:00:00 p. m.        1.007            -
# 1      F           CA  16/6/1958, 7:00:00 p. m.        2.011            -
# 2      F           SO  11/3/1951, 7:00:00 p. m.        1.052            -
#
#    CESION  RIESGOS  CANCER_MAMA_FAMILIAR  CANCER_OTRO_SITIO  \
# 0       0        4                     0                  0
# 1       1        1                     0                  0
# 2       0        2                     0                  0
#
#    CANCER_OTRO_SITIO_FAMILIAR  ...  quimioterapias__cancer  \
# 0                           0  ...                       0
# 1                           0  ...                       0
# 2                           0  ...                       0
#
#   hormonoterapias__cancer cuidado_palitiavo__cancer inmunoterapias_cancer  \
# 0                       0                         0                     0
# 1                       0                         0                     0
# 2                       0                         0                     0
#
#   Citas_oncologicas_cancer psiquiatria_cancer psicologia_cancer  \
# 0                        2                  1                 0
# 1                        0                  0                 0
# 2                        2                  0                 0
#
#   nutricion_cancer       atencion_nutricion     ID
# 0                1   Una servicio nutricion  4.380
# 1                0  Sin servicios nutricion  2.998
# 2                0  Sin servicios nutricion  6.188
#
# [3 rows x 42 columns]

# %%
df.shape
# Out:
# (1000, 42)

# %%
df.describe().T
# Out:
#                              count       mean         std  min      25%  \
# CODIGO_SEDE                 1000.0   1.782758    3.692619  0.0  1.01500
# CESION                      1000.0   0.086000    0.280504  0.0  0.00000
# RIESGOS                     1000.0   1.549000    1.181946  0.0  1.00000
# CANCER_MAMA_FAMILIAR        1000.0   0.084000    0.277527  0.0  0.00000
# CANCER_OTRO_SITIO           1000.0   0.192000    0.394070  0.0  0.00000
# CANCER_OTRO_SITIO_FAMILIAR  1000.0   0.183000    0.386860  0.0  0.00000
# CEREBRAL_FAMILIAR           1000.0   0.018000    0.133018  0.0  0.00000
# IV_NIVEL                    1000.0   5.398000    9.513259  0.0  0.00000
# HOSPI_NO_QUIRURGICA         1000.0   0.035000    0.368661  0.0  0.00000
# URGENCIAS                   1000.0   0.020000    0.235915  0.0  0.00000
# HOSPITALIZACION             1000.0   0.059000    0.530849  0.0  0.00000
# CITA_ONCOLOGICA             1000.0   2.218000    2.318157  0.0  0.00000
# Biopsias_cancer             1000.0   1.247000    2.902484  0.0  0.00000
# radioterapias_cancer        1000.0   0.099000    0.442034  0.0  0.00000
# quimioterapias__cancer      1000.0   0.043000    0.212594  0.0  0.00000
# hormonoterapias__cancer     1000.0   0.455000    0.835867  0.0  0.00000
# cuidado_palitiavo__cancer   1000.0   0.152000    0.512990  0.0  0.00000
# inmunoterapias_cancer       1000.0   0.000000    0.000000  0.0  0.00000
# Citas_oncologicas_cancer    1000.0   2.342000    2.410570  0.0  0.00000
# psiquiatria_cancer          1000.0   0.077000    0.589422  0.0  0.00000
# psicologia_cancer           1000.0   0.199000    0.797518  0.0  0.00000
# nutricion_cancer            1000.0   0.401000    1.169430  0.0  0.00000
# ID                          1000.0  56.027587  177.488350  1.0  2.91425
#
#                                50%      75%      max
# CODIGO_SEDE                 1.0515  1.10825   29.011
# CESION                      0.0000  0.00000    1.000
# RIESGOS                     1.0000  2.00000    6.000
# CANCER_MAMA_FAMILIAR        0.0000  0.00000    1.000
# CANCER_OTRO_SITIO           0.0000  0.00000    1.000
# CANCER_OTRO_SITIO_FAMILIAR  0.0000  0.00000    1.000
# CEREBRAL_FAMILIAR           0.0000  0.00000    1.000
# IV_NIVEL                    1.0000  6.00000   58.000
# HOSPI_NO_QUIRURGICA         0.0000  0.00000    6.000
# URGENCIAS                   0.0000  0.00000    5.000
# HOSPITALIZACION             0.0000  0.00000    7.000
# CITA_ONCOLOGICA             2.0000  3.00000   12.000
# Biopsias_cancer             0.0000  1.00000   25.000
# radioterapias_cancer        0.0000  0.00000    5.000
# quimioterapias__cancer      0.0000  0.00000    2.000
# hormonoterapias__cancer     0.0000  1.00000    7.000
# cuidado_palitiavo__cancer   0.0000  0.00000    6.000
# inmunoterapias_cancer       0.0000  0.00000    0.000
# Citas_oncologicas_cancer    2.0000  3.00000   12.000
# psiquiatria_cancer          0.0000  0.00000   14.000
# psicologia_cancer           0.0000  0.00000   11.000
# nutricion_cancer            0.0000  0.00000   14.000
# ID                          4.8440  6.66325  996.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   GENERO                      1000 non-null   object
#  1   ESTADO_CIVIL                1000 non-null   object
#  2   FECHA_NACIMIENTO            1000 non-null   object
#  3   CODIGO_SEDE                 1000 non-null   float64
#  4   MULTI_CANCER                1000 non-null   object
#  5   CESION                      1000 non-null   int64
#  6   RIESGOS                     1000 non-null   int64
#  7   CANCER_MAMA_FAMILIAR        1000 non-null   int64
#  8   CANCER_OTRO_SITIO           1000 non-null   int64
#  9   CANCER_OTRO_SITIO_FAMILIAR  1000 non-null   int64
#  10  CEREBRAL_FAMILIAR           1000 non-null   int64
#  11  FECHA_DATOS_PESO_TALLA      1000 non-null   object
#  12  PESO                        1000 non-null   object
#  13  TALLA                       1000 non-null   object
#  14  FECHA_CONSULTA_TENSION      1000 non-null   object
#  15  TSISTOLICA                  1000 non-null   object
#  16  TDIASTOLICA                 1000 non-null   object
#  17  Fecha_cero                  1000 non-null   object
#  18  mes_6                       1000 non-null   object
#  19  mes_5                       1000 non-null   object
#  20  mes_4                       1000 non-null   object
#  21  mes_3                       1000 non-null   object
#  22  mes_2                       1000 non-null   object
#  23  mes_1                       1000 non-null   object
#  24  valor_servicio              1000 non-null   object
#  25  IV_NIVEL                    1000 non-null   int64
#  26  HOSPI_NO_QUIRURGICA         1000 non-null   int64
#  27  URGENCIAS                   1000 non-null   int64
#  28  HOSPITALIZACION             1000 non-null   int64
#  29  CITA_ONCOLOGICA             1000 non-null   int64
#  30  Biopsias_cancer             1000 non-null   int64
#  31  radioterapias_cancer        1000 non-null   int64
#  32  quimioterapias__cancer      1000 non-null   int64
#  33  hormonoterapias__cancer     1000 non-null   int64
#  34  cuidado_palitiavo__cancer   1000 non-null   int64
#  35  inmunoterapias_cancer       1000 non-null   int64
#  36  Citas_oncologicas_cancer    1000 non-null   int64
#  37  psiquiatria_cancer          1000 non-null   int64
#  38  psicologia_cancer           1000 non-null   int64
#  39  nutricion_cancer            1000 non-null   int64
#  40  atencion_nutricion          1000 non-null   object
#  41  ID                          1000 non-null   float64
# dtypes: float64(2), int64(21), object(19)
# memory usage: 328.3+ KB

# %% [markdown]
# **II. Understanding**

# %%
df.GENERO.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
sns.countplot(
    x=df.GENERO,
    palette='tab20'
)
# Out:
# <Axes: xlabel='GENERO', ylabel='count'>

# %%
df.ESTADO_CIVIL.unique()
# Out:
# array(['SO', 'CA', 'SE', 'UL', 'VI'], dtype=object)

# %%
sns.countplot(
    x=df.ESTADO_CIVIL,
    palette='tab20'
)
# Out:
# <Axes: xlabel='ESTADO_CIVIL', ylabel='count'>

# %%
df.MULTI_CANCER.unique()
# Out:
# array(['-', '1', '2'], dtype=object)

# %%
df.PESO.unique()
df.PESO=pd.to_numeric(df.PESO,errors='coerce')

# %%
# Definir los límites de los grupos
grupos= [30, 50, 70, 90, 110, 130]

# Definir las etiquetas de los grupos
etiquetas = ['30-50', '50-70', '70-90', '90-110', '110-130']

# Crear una nueva columna en el DataFrame que contenga las categorías de los pesos
df_peso= pd.cut(df['PESO'], bins=grupos, labels=etiquetas, right=False)

# Contar cuántas observaciones hay en cada categoría
pesos_agrupados = df_peso.value_counts().sort_index()

print(pesos_agrupados)
# Out:
# PESO
# 30-50       49
# 50-70      564
# 70-90      233
# 90-110      29
# 110-130      1
# Name: count, dtype: int64

# %%
df_peso = df['PESO']

# Crear el histograma
plt.hist(df_peso, color='skyblue', edgecolor='black')

# Etiquetas y título
plt.xlabel('Peso')
plt.ylabel('Frecuencia')
plt.title('Agrupaciones por peso')

# Mostrar el gráfico
plt.show()

# %%
df.TALLA.value_counts() #pdte -> imputar
# Out:
# TALLA
# 160    91
# 155    87
# 150    71
# 158    59
# 156    50
# 157    45
# 162    43
# 152    43
# 159    38
# -      38
# 153    38
# 165    36
# 154    36
# 164    33
# 148    29
# 151    26
# 163    24
# 149    22
# 170    21
# 147    21
# 168    19
# 161    17
# 146    14
# 166    12
# 144    12
# 145    11
# 142    10
# 174     7
# 167     7
# 143     6
# 169     6
# 172     5
# 141     5
# 176     3
# 173     2
# 177     2
# 171     2
# 178     1
# 175     1
# 137     1
# 136     1
# 184     1
# 132     1
# 140     1
# 139     1
# 131     1
# Name: count, dtype: int64

# %%
df_clean = df[df['TALLA'] != '-']
df_clean['TALLA'] = pd.to_numeric(df_clean['TALLA'], errors='coerce')

# Definir los límites de los grupos
grupos = [130, 150, 170, 190]

# Definir las etiquetas de los grupos
etiquetas = ['130-150', '150-170', '170-190']

# Crear una nueva columna en el DataFrame que contenga las categorías de las tallas
df_talla = pd.cut(df_clean['TALLA'], bins=grupos, labels=etiquetas)#, right=False)

# Contar cuántas observaciones hay en cada categoría
talla_agrupados = df_talla.value_counts().sort_index()

print(talla_agrupados)
# Out:
# TALLA
# 130-150    207
# 150-170    731
# 170-190     24
# Name: count, dtype: int64

# %%
plt.hist(talla_agrupados.index, bins=len(talla_agrupados), weights=talla_agrupados.values, color='skyblue', edgecolor='black')

# Etiquetas y título
plt.xlabel('Talla')
plt.ylabel('Frecuencia')
plt.title('Histograma de Agrupación de Tallas')

# Mostrar el gráfico
plt.show()

# %%
df.URGENCIAS.unique()
# Out:
# array([0, 1, 2, 4, 5], dtype=int64)

# %%
filtered_df = df[df['URGENCIAS'] > 0]
sns.countplot(x=filtered_df['URGENCIAS'], palette='tab20')
plt.title('Pacientes por urgencias')
plt.show()

# %%
pd.crosstab(index=df['CANCER_MAMA_FAMILIAR'],columns='count')
pd.crosstab(index=df['CANCER_OTRO_SITIO'],columns='count')
pd.crosstab(index=df['CANCER_OTRO_SITIO_FAMILIAR'],columns='count')
pd.crosstab(index=df['CEREBRAL_FAMILIAR'],columns='count')
# Out:
# col_0              count
# CEREBRAL_FAMILIAR
# 0                    982
# 1                     18

# %% [markdown]
# # Antecedentes

# %%
df_cancer = df[['CANCER_MAMA_FAMILIAR','CANCER_OTRO_SITIO','CANCER_OTRO_SITIO_FAMILIAR','CEREBRAL_FAMILIAR']]
print(df_cancer.shape)
porcentaje = df_cancer.apply(lambda x: x.value_counts(normalize=True) * 100)
ax = porcentaje.plot(kind='bar')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}%', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=9, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.xlabel('Antecedentes')
plt.ylabel('%')
plt.title('% de Antecedentes')

plt.show()
# Out:
# (1000, 4)

# %%
#Presión Sistolica y diastolica (Contrae y relaja)
df.TSISTOLICA.unique() 
df.TDIASTOLICA.unique()
# Out:
# array(['80', '60', '-', '64', '85', '70', '72', '63', '91', '74', '79',
#        '78', '68', '90', '50', '89', '73', '65', '77', '75', '83', '76',
#        '62', '84', '82', '86', '88', '94', '71', '66', '61', '87', '104',
#        '100', '67', '81', '69', '92', '55', '56', '58'], dtype=object)

# %%
# Reemplazar los '-' con NaN para poder graficar
df.replace('-', float('nan'), inplace=True)
# Convertir las columnas a tipo numérico
df['TSISTOLICA'] = pd.to_numeric(df['TSISTOLICA'])
df['TDIASTOLICA'] = pd.to_numeric(df['TDIASTOLICA'])

# Graficar
plt.plot(df.index, df['TSISTOLICA'], marker='.', label='TSISTOLICA')
plt.plot(df.index, df['TDIASTOLICA'], marker='.', label='TDIASTOLICA')
plt.xlabel('Muestras')
plt.ylabel('Presión')
plt.title('Presión Sistólica y Diastólica')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## to_datetime

# %%
# Convertir la columna de fecha de nacimiento al formato de fecha
df['FECHA_NACIMIENTO'] = pd.to_datetime(df['FECHA_NACIMIENTO'])
df['FECHA_DATOS_PESO_TALLA']=pd.to_datetime(df['FECHA_DATOS_PESO_TALLA'])
df['Fecha_cero']=pd.to_datetime(df['Fecha_cero'])

# %%
df['Fecha_cero'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Calcular la edad de las mujeres a hoy
from datetime import datetime
today = datetime.now()
df['Edad'] = today.year - df['FECHA_NACIMIENTO'].dt.year

# %% [markdown]
# # Edades de los pacientes

# %%
# Graficar un histograma de edades de las mujeres
plt.hist(df['Edad'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades de Pacientes')
plt.grid(True)
plt.show()

# %% [markdown]
# # Complicaciones

# %%
# Contar el número de consultas por complicaciones por cada día
consulta_por_dia = df['Fecha_cero'].value_counts().sort_index()

# Graficar un diagrama de líneas de la distribución de fechas de consulta por complicaciones
plt.plot(consulta_por_dia.index, consulta_por_dia.values, marker='*', color='blue')
plt.xlabel('Fecha de Consulta por Complicaciones')
plt.ylabel('Número de Consultas')
plt.title('Distribución de Consultas por Complicaciones a lo largo del Tiempo')
plt.xticks(rotation=45) 
plt.grid(True)
plt.show()

# %%
# Convertir las columnas a tipo numérico (float)
columnas_NUMER = ['mes_1', 'mes_2', 'mes_3', 'mes_4', 'mes_5', 'mes_6', 'PESO', 'TALLA', 'TDIASTOLICA','TSISTOLICA','valor_servicio']
df[columnas_NUMER] = df[columnas_NUMER].apply(pd.to_numeric, errors='coerce')
print(df.dtypes)
# Out:
# GENERO                                object
# ESTADO_CIVIL                          object
# FECHA_NACIMIENTO              datetime64[ns]
# CODIGO_SEDE                          float64
# MULTI_CANCER                          object
# CESION                                 int64
# RIESGOS                                int64
# CANCER_MAMA_FAMILIAR                   int64
# CANCER_OTRO_SITIO                      int64
# CANCER_OTRO_SITIO_FAMILIAR             int64
# CEREBRAL_FAMILIAR                      int64
# FECHA_DATOS_PESO_TALLA        datetime64[ns]
# PESO                                 float64
# TALLA                                float64
# FECHA_CONSULTA_TENSION                object
# TSISTOLICA                           float64
# TDIASTOLICA                          float64
# Fecha_cero                    datetime64[ns]
# mes_6                                float64
# mes_5                                float64
# mes_4                                float64
# mes_3                                float64
# mes_2                                float64
# mes_1                                float64
# valor_servicio                       float64
# IV_NIVEL                               int64
# HOSPI_NO_QUIRURGICA                    int64
# URGENCIAS                              int64
# HOSPITALIZACION                        int64
# CITA_ONCOLOGICA                        int64
# Biopsias_cancer                        int64
# radioterapias_cancer                   int64
# quimioterapias__cancer                 int64
# hormonoterapias__cancer                int64
# cuidado_palitiavo__cancer              int64
# inmunoterapias_cancer                  int64
# Citas_oncologicas_cancer               int64
# psiquiatria_cancer                     int64
# psicologia_cancer                      int64
# nutricion_cancer                       int64
# atencion_nutricion                    object
# ID                                   float64
# Edad                                   int32
# dtype: object

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10), sharey=True)

# Definir los meses
meses = ['mes_1', 'mes_2', 'mes_3', 'mes_4', 'mes_5', 'mes_6']

# Iterar sobre los ejes y los meses para graficar
for i, ax in enumerate(axs.flat):
    mes_actual = meses[i]
    ax.bar(df.index, df[mes_actual], color='blue')
    ax.set_title(f'Diagrama de Barras para {mes_actual}')
    ax.set_xlabel('Índice')
    ax.set_ylabel('Valor')

# Ajustar el espaciado entre subplots
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df.HOSPITALIZACION
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: HOSPITALIZACION, Length: 1000, dtype: int64

# %%
filtered_df = df[df['HOSPITALIZACION'] > 0]
sns.countplot(x=filtered_df['HOSPITALIZACION'], palette='tab20')
plt.title('Pacientes Hospitalización')
plt.show()

# %%
filtered_df = df[df['HOSPITALIZACION'] > 0]

# Contar el número de ocurrencias para cada valor de 'HOSPITALIZACION'
counts = filtered_df['HOSPITALIZACION'].value_counts()

# Calcular los porcentajes
total = counts.sum()
porcentajes = [(count / total) * 100 for count in counts]

# Crear el gráfico
sns.countplot(x=filtered_df['HOSPITALIZACION'], palette='tab20')

# Anotar los porcentajes en el gráfico
for i, count in enumerate(counts):
    plt.text(i, count + 0.5, f'{porcentajes[i]:.2f}%')

plt.title('Pacientes con Hospitalización')
plt.show()

# %% [markdown]
# # Matriz de correlación

# %%
# Imputar los valores '-'
df.replace('-', np.nan, inplace=True)

# Convertir las columnas numéricas a tipo de datos numéricos
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns] = df[numeric_columns].astype(float)

# Filtrar solo los datos numéricos
numeric_df = df[numeric_columns]

# Calcular la matriz de correlación
correlation_matrix = numeric_df.corr()

# Mostrar la matriz de correlación
print("Matriz de correlación:")
print(correlation_matrix)
# Out:
# Matriz de correlación:
#                             CODIGO_SEDE    CESION   RIESGOS  \
# CODIGO_SEDE                    1.000000  0.395400  0.038282
# CESION                         0.395400  1.000000  0.026527
# RIESGOS                        0.038282  0.026527  1.000000
# CANCER_MAMA_FAMILIAR          -0.012374 -0.041456 -0.036974
# CANCER_OTRO_SITIO             -0.099229 -0.113305 -0.009473
# CANCER_OTRO_SITIO_FAMILIAR    -0.094530 -0.117501 -0.040428
# CEREBRAL_FAMILIAR             -0.029056 -0.041529 -0.031083
# PESO                           0.050861  0.056423  0.155200
# TALLA                          0.008706 -0.001700 -0.141641
# TSISTOLICA                     0.023473  0.042615  0.167720
# TDIASTOLICA                    0.035199  0.036911  0.094246
# mes_6                          0.000785  0.013968 -0.015635
# mes_5                         -0.007728 -0.013368 -0.065835
# mes_4                         -0.051781  0.026595 -0.049871
# mes_3                          0.015786  0.018808 -0.037115
# mes_2                         -0.011568 -0.032810 -0.031492
# mes_1                         -0.002362 -0.033506 -0.072176
# valor_servicio                 0.001099 -0.009064  0.025027
# IV_NIVEL                      -0.047370 -0.059729 -0.073401
# HOSPI_NO_QUIRURGICA           -0.007483 -0.029136  0.022479
# URGENCIAS                      0.100119  0.019362 -0.021468
# HOSPITALIZACION               -0.014182 -0.000497 -0.026150
# CITA_ONCOLOGICA               -0.025305  0.009624 -0.047012
# Biopsias_cancer               -0.049474 -0.029805 -0.075165
# radioterapias_cancer           0.043608  0.068508 -0.012168
# quimioterapias__cancer        -0.038992 -0.011717 -0.121929
# hormonoterapias__cancer       -0.031626 -0.026171 -0.048426
# cuidado_palitiavo__cancer     -0.011211 -0.028327 -0.000740
# inmunoterapias_cancer               NaN       NaN       NaN
# Citas_oncologicas_cancer      -0.027575  0.003831 -0.045588
# psiquiatria_cancer            -0.021676 -0.009820  0.034092
# psicologia_cancer              0.017215  0.044236 -0.017257
# nutricion_cancer              -0.035181 -0.016741  0.123007
# ID                             0.073417  0.158227 -0.025632
# Edad                          -0.051633 -0.005828  0.444940
#
#                             CANCER_MAMA_FAMILIAR  CANCER_OTRO_SITIO  \
# CODIGO_SEDE                            -0.012374          -0.099229
# CESION                                 -0.041456          -0.113305
# RIESGOS                                -0.036974          -0.009473
# CANCER_MAMA_FAMILIAR                    1.000000           0.209344
# CANCER_OTRO_SITIO                       0.209344           1.000000
# CANCER_OTRO_SITIO_FAMILIAR              0.192324           0.596622
# CEREBRAL_FAMILIAR                       0.040348           0.144063
# PESO                                   -0.073769           0.028861
# TALLA                                   0.006287           0.018745
# TSISTOLICA                             -0.023777           0.010737
# TDIASTOLICA                            -0.018824          -0.033127
# mes_6                                  -0.081836           0.005528
# mes_5                                   0.007626          -0.033595
# mes_4                                  -0.017763           0.014019
# mes_3                                  -0.002160           0.119731
# mes_2                                   0.024207           0.068026
# mes_1                                  -0.003696           0.051781
# valor_servicio                          0.006647          -0.001840
# IV_NIVEL                               -0.036940          -0.034823
# HOSPI_NO_QUIRURGICA                    -0.028764          -0.046302
# URGENCIAS                              -0.025685          -0.030579
# HOSPITALIZACION                        -0.033674          -0.044635
# CITA_ONCOLOGICA                        -0.019156          -0.040386
# Biopsias_cancer                         0.012740           0.138781
# radioterapias_cancer                    0.021901          -0.011539
# quimioterapias__cancer                  0.057481           0.008890
# hormonoterapias__cancer                 0.081038           0.099191
# cuidado_palitiavo__cancer               0.015693           0.028799
# inmunoterapias_cancer                        NaN                NaN
# Citas_oncologicas_cancer               -0.016052          -0.036527
# psiquiatria_cancer                      0.058329          -0.016307
# psicologia_cancer                      -0.025851          -0.022958
# nutricion_cancer                       -0.011363           0.006534
# ID                                      0.023735           0.013616
# Edad                                   -0.018724          -0.041237
#
#                             CANCER_OTRO_SITIO_FAMILIAR  CEREBRAL_FAMILIAR  \
# CODIGO_SEDE                                  -0.094530          -0.029056
# CESION                                       -0.117501          -0.041529
# RIESGOS                                      -0.040428          -0.031083
# CANCER_MAMA_FAMILIAR                          0.192324           0.040348
# CANCER_OTRO_SITIO                             0.596622           0.144063
# CANCER_OTRO_SITIO_FAMILIAR                    1.000000           0.130447
# CEREBRAL_FAMILIAR                             0.130447           1.000000
# PESO                                          0.001007          -0.025837
# TALLA                                         0.013633          -0.012897
# TSISTOLICA                                   -0.037344           0.009588
# TDIASTOLICA                                  -0.025888           0.017150
# mes_6                                        -0.029315          -0.011812
# mes_5                                        -0.047777           0.042862
# mes_4                                        -0.023495           0.011113
# mes_3                                         0.086479           0.039625
# mes_2                                         0.051455          -0.009825
# mes_1                                         0.079485          -0.043773
# valor_servicio                                0.043646           0.047424
# IV_NIVEL                                     -0.060336          -0.039682
# HOSPI_NO_QUIRURGICA                          -0.044954          -0.012860
# URGENCIAS                                    -0.018207          -0.011483
# HOSPITALIZACION                              -0.052627          -0.015055
# CITA_ONCOLOGICA                              -0.069085          -0.054940
# Biopsias_cancer                               0.065790           0.019585
# radioterapias_cancer                         -0.065075          -0.013313
# quimioterapias__cancer                        0.025937           0.008000
# hormonoterapias__cancer                       0.088952           0.016295
# cuidado_palitiavo__cancer                     0.016060          -0.025466
# inmunoterapias_cancer                              NaN                NaN
# Citas_oncologicas_cancer                     -0.061813          -0.059801
# psiquiatria_cancer                            0.008380           0.007839
# psicologia_cancer                            -0.027308          -0.024364
# nutricion_cancer                              0.005790          -0.007838
# ID                                            0.045789          -0.024325
# Edad                                         -0.015833          -0.001593
#
#                                 PESO     TALLA  TSISTOLICA  ...  \
# CODIGO_SEDE                 0.050861  0.008706    0.023473  ...
# CESION                      0.056423 -0.001700    0.042615  ...
# RIESGOS                     0.155200 -0.141641    0.167720  ...
# CANCER_MAMA_FAMILIAR       -0.073769  0.006287   -0.023777  ...
# CANCER_OTRO_SITIO           0.028861  0.018745    0.010737  ...
# CANCER_OTRO_SITIO_FAMILIAR  0.001007  0.013633   -0.037344  ...
# CEREBRAL_FAMILIAR          -0.025837 -0.012897    0.009588  ...
# PESO                        1.000000  0.356870    0.103425  ...
# TALLA                       0.356870  1.000000   -0.075156  ...
# TSISTOLICA                  0.103425 -0.075156    1.000000  ...
# TDIASTOLICA                 0.127313  0.019630    0.473153  ...
# mes_6                       0.020601  0.006974   -0.033227  ...
# mes_5                       0.018948  0.046669   -0.000146  ...
# mes_4                      -0.025416  0.002267   -0.049590  ...
# mes_3                      -0.069285  0.023050    0.001228  ...
# mes_2                       0.011870 -0.022984   -0.027709  ...
# mes_1                       0.024538  0.043313   -0.007173  ...
# valor_servicio             -0.008996 -0.030024   -0.010405  ...
# IV_NIVEL                   -0.085917 -0.018928    0.026104  ...
# HOSPI_NO_QUIRURGICA        -0.073558 -0.063489   -0.005782  ...
# URGENCIAS                  -0.033793  0.029820   -0.011761  ...
# HOSPITALIZACION             0.001779 -0.016480   -0.009024  ...
# CITA_ONCOLOGICA            -0.058583  0.023738   -0.006142  ...
# Biopsias_cancer            -0.016549  0.039830   -0.002619  ...
# radioterapias_cancer       -0.007955  0.000216    0.069231  ...
# quimioterapias__cancer     -0.052494 -0.020657    0.020020  ...
# hormonoterapias__cancer    -0.040271  0.055547   -0.005377  ...
# cuidado_palitiavo__cancer  -0.026673 -0.029742   -0.037441  ...
# inmunoterapias_cancer            NaN       NaN         NaN  ...
# Citas_oncologicas_cancer   -0.062514  0.023618   -0.003391  ...
# psiquiatria_cancer         -0.037333  0.039333   -0.002206  ...
# psicologia_cancer          -0.045784  0.071991   -0.018505  ...
# nutricion_cancer           -0.092022 -0.014603    0.032211  ...
# ID                         -0.003525 -0.010847   -0.001228  ...
# Edad                       -0.057854 -0.293144    0.229963  ...
#
#                             quimioterapias__cancer  hormonoterapias__cancer  \
# CODIGO_SEDE                              -0.038992                -0.031626
# CESION                                   -0.011717                -0.026171
# RIESGOS                                  -0.121929                -0.048426
# CANCER_MAMA_FAMILIAR                      0.057481                 0.081038
# CANCER_OTRO_SITIO                         0.008890                 0.099191
# CANCER_OTRO_SITIO_FAMILIAR                0.025937                 0.088952
# CEREBRAL_FAMILIAR                         0.008000                 0.016295
# PESO                                     -0.052494                -0.040271
# TALLA                                    -0.020657                 0.055547
# TSISTOLICA                                0.020020                -0.005377
# TDIASTOLICA                              -0.047208                -0.031361
# mes_6                                     0.075545                 0.050743
# mes_5                                     0.146311                 0.048655
# mes_4                                     0.214069                 0.109705
# mes_3                                     0.147421                 0.144838
# mes_2                                     0.315873                 0.163283
# mes_1                                     0.192002                 0.125700
# valor_servicio                            0.014777                 0.199682
# IV_NIVEL                                  0.438957                 0.024410
# HOSPI_NO_QUIRURGICA                       0.057410                -0.048482
# URGENCIAS                                 0.022753                -0.000508
# HOSPITALIZACION                           0.012976                 0.013885
# CITA_ONCOLOGICA                           0.236884                -0.026445
# Biopsias_cancer                           0.203394                 0.408726
# radioterapias_cancer                      0.039870                 0.018842
# quimioterapias__cancer                    1.000000                 0.053148
# hormonoterapias__cancer                   0.053148                 1.000000
# cuidado_palitiavo__cancer                 0.160294                 0.069661
# inmunoterapias_cancer                          NaN                      NaN
# Citas_oncologicas_cancer                  0.227154                -0.032098
# psiquiatria_cancer                       -0.026449                 0.006024
# psicologia_cancer                         0.026231                 0.069757
# nutricion_cancer                          0.055390                 0.014895
# ID                                       -0.010236                 0.064979
# Edad                                     -0.171763                -0.003566
#
#                             cuidado_palitiavo__cancer  inmunoterapias_cancer  \
# CODIGO_SEDE                                 -0.011211                    NaN
# CESION                                      -0.028327                    NaN
# RIESGOS                                     -0.000740                    NaN
# CANCER_MAMA_FAMILIAR                         0.015693                    NaN
# CANCER_OTRO_SITIO                            0.028799                    NaN
# CANCER_OTRO_SITIO_FAMILIAR                   0.016060                    NaN
# CEREBRAL_FAMILIAR                           -0.025466                    NaN
# PESO                                        -0.026673                    NaN
# TALLA                                       -0.029742                    NaN
# TSISTOLICA                                  -0.037441                    NaN
# TDIASTOLICA                                 -0.050681                    NaN
# mes_6                                        0.127760                    NaN
# mes_5                                        0.067555                    NaN
# mes_4                                        0.155114                    NaN
# mes_3                                        0.205887                    NaN
# mes_2                                        0.267888                    NaN
# mes_1                                        0.270764                    NaN
# valor_servicio                               0.112597                    NaN
# IV_NIVEL                                     0.256906                    NaN
# HOSPI_NO_QUIRURGICA                          0.548773                    NaN
# URGENCIAS                                    0.065839                    NaN
# HOSPITALIZACION                             -0.032965                    NaN
# CITA_ONCOLOGICA                              0.262511                    NaN
# Biopsias_cancer                              0.171068                    NaN
# radioterapias_cancer                         0.136634                    NaN
# quimioterapias__cancer                       0.160294                    NaN
# hormonoterapias__cancer                      0.069661                    NaN
# cuidado_palitiavo__cancer                    1.000000                    NaN
# inmunoterapias_cancer                             NaN                    NaN
# Citas_oncologicas_cancer                     0.264713                    NaN
# psiquiatria_cancer                          -0.018883                    NaN
# psicologia_cancer                            0.178004                    NaN
# nutricion_cancer                             0.310439                    NaN
# ID                                           0.010517                    NaN
# Edad                                        -0.022899                    NaN
#
#                             Citas_oncologicas_cancer  psiquiatria_cancer  \
# CODIGO_SEDE                                -0.027575           -0.021676
# CESION                                      0.003831           -0.009820
# RIESGOS                                    -0.045588            0.034092
# CANCER_MAMA_FAMILIAR                       -0.016052            0.058329
# CANCER_OTRO_SITIO                          -0.036527           -0.016307
# CANCER_OTRO_SITIO_FAMILIAR                 -0.061813            0.008380
# CEREBRAL_FAMILIAR                          -0.059801            0.007839
# PESO                                       -0.062514           -0.037333
# TALLA                                       0.023618            0.039333
# TSISTOLICA                                 -0.003391           -0.002206
# TDIASTOLICA                                -0.051748            0.033276
# mes_6                                       0.368590           -0.005105
# mes_5                                       0.360964           -0.024143
# mes_4                                       0.385348           -0.043886
# mes_3                                       0.359812           -0.040001
# mes_2                                       0.393743           -0.015102
# mes_1                                       0.322059            0.000731
# valor_servicio                              0.352958           -0.028471
# IV_NIVEL                                    0.641914           -0.032427
# HOSPI_NO_QUIRURGICA                         0.117178            0.015225
# URGENCIAS                                   0.063649            0.075298
# HOSPITALIZACION                             0.089037           -0.014534
# CITA_ONCOLOGICA                             0.979929           -0.035008
# Biopsias_cancer                             0.027688           -0.025756
# radioterapias_cancer                        0.219957           -0.029287
# quimioterapias__cancer                      0.227154           -0.026449
# hormonoterapias__cancer                    -0.032098            0.006024
# cuidado_palitiavo__cancer                   0.264713           -0.018883
# inmunoterapias_cancer                            NaN                 NaN
# Citas_oncologicas_cancer                    1.000000           -0.038279
# psiquiatria_cancer                         -0.038279            1.000000
# psicologia_cancer                           0.128058            0.127079
# nutricion_cancer                            0.159386            0.046650
# ID                                         -0.000472            0.005755
# Edad                                       -0.187855           -0.015443
#
#                             psicologia_cancer  nutricion_cancer        ID  \
# CODIGO_SEDE                          0.017215         -0.035181  0.073417
# CESION                               0.044236         -0.016741  0.158227
# RIESGOS                             -0.017257          0.123007 -0.025632
# CANCER_MAMA_FAMILIAR                -0.025851         -0.011363  0.023735
# CANCER_OTRO_SITIO                   -0.022958          0.006534  0.013616
# CANCER_OTRO_SITIO_FAMILIAR          -0.027308          0.005790  0.045789
# CEREBRAL_FAMILIAR                   -0.024364         -0.007838 -0.024325
# PESO                                -0.045784         -0.092022 -0.003525
# TALLA                                0.071991         -0.014603 -0.010847
# TSISTOLICA                          -0.018505          0.032211 -0.001228
# TDIASTOLICA                         -0.005068         -0.003869  0.047748
# mes_6                                0.163906          0.076168  0.006878
# mes_5                                0.036202          0.009062  0.021830
# mes_4                                0.118565          0.105554  0.046231
# mes_3                                0.076414          0.101383 -0.006236
# mes_2                                0.131371          0.135047  0.005173
# mes_1                                0.092553          0.099402 -0.011028
# valor_servicio                      -0.012172         -0.027530  0.013200
# IV_NIVEL                             0.068844          0.124114 -0.009624
# HOSPI_NO_QUIRURGICA                  0.023951          0.153160 -0.011842
# URGENCIAS                            0.032028          0.061609  0.012307
# HOSPITALIZACION                     -0.027761         -0.017187  0.043835
# CITA_ONCOLOGICA                      0.126490          0.152714  0.003784
# Biopsias_cancer                      0.080367          0.038619 -0.004238
# radioterapias_cancer                 0.009367          0.029629  0.018829
# quimioterapias__cancer               0.026231          0.055390 -0.010236
# hormonoterapias__cancer              0.069757          0.014895  0.064979
# cuidado_palitiavo__cancer            0.178004          0.310439  0.010517
# inmunoterapias_cancer                     NaN               NaN       NaN
# Citas_oncologicas_cancer             0.128058          0.159386 -0.000472
# psiquiatria_cancer                   0.127079          0.046650  0.005755
# psicologia_cancer                    1.000000          0.185896 -0.013520
# nutricion_cancer                     0.185896          1.000000  0.001012
# ID                                  -0.013520          0.001012  1.000000
# Edad                                -0.077205          0.038809  0.058644
#
#                                 Edad
# CODIGO_SEDE                -0.051633
# CESION                     -0.005828
# RIESGOS                     0.444940
# CANCER_MAMA_FAMILIAR       -0.018724
# CANCER_OTRO_SITIO          -0.041237
# CANCER_OTRO_SITIO_FAMILIAR -0.015833
# CEREBRAL_FAMILIAR          -0.001593
# PESO                       -0.057854
# TALLA                      -0.293144
# TSISTOLICA                  0.229963
# TDIASTOLICA                 0.102476
# mes_6                      -0.124277
# mes_5                      -0.083818
# mes_4                      -0.069399
# mes_3                      -0.070964
# mes_2                      -0.077320
# mes_1                      -0.078388
# valor_servicio             -0.051130
# IV_NIVEL                   -0.166825
# HOSPI_NO_QUIRURGICA         0.017024
# URGENCIAS                  -0.035628
# HOSPITALIZACION            -0.082435
# CITA_ONCOLOGICA            -0.180236
# Biopsias_cancer            -0.112173
# radioterapias_cancer       -0.003172
# quimioterapias__cancer     -0.171763
# hormonoterapias__cancer    -0.003566
# cuidado_palitiavo__cancer  -0.022899
# inmunoterapias_cancer            NaN
# Citas_oncologicas_cancer   -0.187855
# psiquiatria_cancer         -0.015443
# psicologia_cancer          -0.077205
# nutricion_cancer            0.038809
# ID                          0.058644
# Edad                        1.000000
#
# [35 rows x 35 columns]

# %%
# Visualizar la matriz de correlación como un mapa de calor
plt.figure(figsize=(25, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.2)
plt.title('Matriz de Correlación')
plt.show()
